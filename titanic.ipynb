# %%
import pandas as pd
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load in dataset

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # View shape of data

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %% [markdown]
# # View missing data

# %%
msno.matrix(train)

# %% [markdown]
# Seems to be some missing values in Age and a lot in Cabin.

# %%
msno.matrix(test)

# %% [markdown]
# Similarly, missing values in age and cabin, also missing value in Fare

# %% [markdown]
# # Describe data

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## View number of unique values in each feature

# %%
for col in train.columns:
    print(col, len(train[col].unique()))
# Out:
# PassengerId 891
# Survived 2
# Pclass 3
# Name 891
# Sex 2
# Age 89
# SibSp 7
# Parch 7
# Ticket 681
# Fare 248
# Cabin 148
# Embarked 4

# %%
for col in test.columns:
    print(col, len(test[col].unique()))
# Out:
# PassengerId 418
# Pclass 3
# Name 418
# Sex 2
# Age 80
# SibSp 7
# Parch 8
# Ticket 363
# Fare 170
# Cabin 77
# Embarked 3

# %% [markdown]
# ## Look at Pclass (Ticket Class)

# %%
train['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# 1: 1st <br>
# 2: 2nd <br>
# 3: 3rd <br>

# %% [markdown]
# ## Look at Name

# %%
train['Name'].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %% [markdown]
# ## Look at SibSp (# siblings and spouses on the train)

# %%
train['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %% [markdown]
# ## Look at Parch (# parents/spouse aboard the train)

# %%
train['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %% [markdown]
# ## Look at ticket number

# %%
train['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
len(train['Ticket'].unique())
# Out:
# 681

# %%
train.groupby('Ticket').Survived.count()
# Out:
# Ticket
# 110152               3
# 110413               3
# 110465               2
# 110564               1
# 110813               1
# 111240               1
# 111320               1
# 111361               2
# 111369               1
# 111426               1
# 111427               1
# 111428               1
# 112050               1
# 112052               1
# 112053               1
# 112058               1
# 112059               1
# 112277               1
# 112379               1
# 113028               1
# 113043               1
# 113050               1
# 113051               1
# 113055               1
# 113056               1
# 113059               1
# 113501               1
# 113503               1
# 113505               2
# 113509               1
#                     ..
# SOTON/OQ 392082      1
# SOTON/OQ 392086      1
# SOTON/OQ 392089      1
# SOTON/OQ 392090      1
# STON/O 2. 3101269    1
# STON/O 2. 3101273    1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# ...

# %%
train[train['Ticket'] == '110152']
# Out:
#      PassengerId  Survived  Pclass  \
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 257      0  110152  86.5   B77        S
# 504      0  110152  86.5   B79        S
# 759      0  110152  86.5   B77        S

# %% [markdown]
# People travelling together had same ticket number

# %% [markdown]
# ## Look at fare

# %%
train['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %% [markdown]
# ## Look at cabin

# %%
train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
len(train['Cabin'].unique())
# Out:
# 148

# %% [markdown]
# Boat Deck: 6 rooms labelled T,U,W,X,Y,Z but only T is present
# A,B,C : First Class Cabins
# D,E : All classes
# F,G : 2nd and 34d Class Cabins

# %% [markdown]
# ## Look at embarked

# %%
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# S: Southampton
# C: Cherbourg
# Q: Queenstown

# %%
sum(train['Embarked'].isnull())
# Out:
# 2

# %%
train[train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# Google says both of these passengers embarked in Southampton

# %%
train.at[(61, 829), 'Embarked'] = 'S'
train.loc[(61, 829), :]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28        S
# 829  female  62.0      0      0  113572  80.0   B28        S

# %% [markdown]
# ## Look at age

# %%
train[train['Sex'] == 'female'].Age.mean()
# Out:
# 27.915708812260537

# %%
train[train['Sex'] == 'male'].Age.mean()
# Out:
# 30.72664459161148

# %%
sns.boxplot(x = train['Age'])

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.pairplot(data = train, hue = "Survived")

# %%
sns.catplot(x="Sex", y="Age", hue="Survived", data=train)

# %% [markdown]
# Females had higher chance of survival

# %% [markdown]
# ## Embarked location vs survival

# %%
sns.catplot(y="Embarked", hue="Survived", kind = 'count', data=train)

# %% [markdown]
# The titanic started in Southampton, then went to Cherbourg (France) and then Queenstown (Ireland)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Feature engineer name

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
name_df = train['Name'].str.split(',', expand = True)
name_df
# Out:
#                    0                                                  1
# 0             Braund                                    Mr. Owen Harris
# 1            Cumings         Mrs. John Bradley (Florence Briggs Thayer)
# 2          Heikkinen                                        Miss. Laina
# 3           Futrelle                 Mrs. Jacques Heath (Lily May Peel)
# 4              Allen                                  Mr. William Henry
# 5              Moran                                          Mr. James
# 6           McCarthy                                      Mr. Timothy J
# 7            Palsson                              Master. Gosta Leonard
# 8            Johnson           Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             Nasser                        Mrs. Nicholas (Adele Achem)
# 10         Sandstrom                               Miss. Marguerite Rut
# 11           Bonnell                                    Miss. Elizabeth
# ...

# %% [markdown]
# ### Create df for surname

# %%
surname_df = name_df.loc[:,0]
surname_df.columns = ['Surname']
surname_df
# Out:
# 0               Braund
# 1              Cumings
# 2            Heikkinen
# 3             Futrelle
# 4                Allen
# 5                Moran
# 6             McCarthy
# 7              Palsson
# 8              Johnson
# 9               Nasser
# 10           Sandstrom
# 11             Bonnell
# 12         Saundercock
# 13           Andersson
# 14             Vestrom
# 15             Hewlett
# 16                Rice
# 17            Williams
# 18       Vander Planke
# 19          Masselmani
# 20              Fynney
# 21             Beesley
# 22             McGowan
# 23              Sloper
# 24             Palsson
# 25             Asplund
# 26                Emir
# 27             Fortune
# 28             O'Dwyer
# 29            Todoroff
#             ...
# 861              Giles
# 862              Swift
# 863               Sage
# 864               Gill
# 865            Bystrom
# 866       Duran y More
# 867           Roebling
# 868      van Melkebeke
# 869            Johnson
# ...

# %% [markdown]
# ### Create df for firstname and title

# %%
title_firstname = name_df[1].str.split('.', expand = True)
title_firstname
# Out:
#            0                                             1     2
# 0         Mr                                   Owen Harris  None
# 1        Mrs         John Bradley (Florence Briggs Thayer)  None
# 2       Miss                                         Laina  None
# 3        Mrs                 Jacques Heath (Lily May Peel)  None
# 4         Mr                                 William Henry  None
# 5         Mr                                         James  None
# 6         Mr                                     Timothy J  None
# 7     Master                                 Gosta Leonard  None
# 8        Mrs           Oscar W (Elisabeth Vilhelmina Berg)  None
# 9        Mrs                        Nicholas (Adele Achem)  None
# 10      Miss                                Marguerite Rut  None
# 11      Miss                                     Elizabeth  None
# 12        Mr                                 William Henry  None
# ...

# %%
title_firstname = title_firstname.loc[:,[0,1]]
title_firstname.columns = ['Title', 'Firstname']
title_firstname
# Out:
#        Title                                     Firstname
# 0         Mr                                   Owen Harris
# 1        Mrs         John Bradley (Florence Briggs Thayer)
# 2       Miss                                         Laina
# 3        Mrs                 Jacques Heath (Lily May Peel)
# 4         Mr                                 William Henry
# 5         Mr                                         James
# 6         Mr                                     Timothy J
# 7     Master                                 Gosta Leonard
# 8        Mrs           Oscar W (Elisabeth Vilhelmina Berg)
# 9        Mrs                        Nicholas (Adele Achem)
# 10      Miss                                Marguerite Rut
# 11      Miss                                     Elizabeth
# 12        Mr                                 William Henry
# 13        Mr                                  Anders Johan
# 14      Miss                         Hulda Amanda Adolfina
# ...

# %% [markdown]
# ### Combine with train

# %%
train.loc[:,'Surname'] = surname_df
train[['Title', 'Firstname']] = title_firstname
train.drop('Name', axis = 1, inplace = True)
train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 5              6         0       3    male   NaN      0      0
# 6              7         0       1    male  54.0      0      0
# 7              8         0       3    male   2.0      3      1
# 8              9         1       3  female  27.0      0      2
# 9             10         1       2  female  14.0      1      0
# 10            11         1       3  female   4.0      1      1
# 11            12         1       1  female  58.0      0      0
# 12            13         0       3    male  20.0      0      0
# 13            14         0       3    male  39.0      1      5
# ...

# %%
train.Title.unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Master', ' Don', ' Rev', ' Dr', ' Mme',
#        ' Ms', ' Major', ' Lady', ' Sir', ' Mlle', ' Col', ' Capt',
#        ' the Countess', ' Jonkheer'], dtype=object)

# %% [markdown]
# # Convert Miss,Mme,Ms,Lady,Mlle, the Countess to Miss

# %%
train['Title'].replace([' Miss', ' Mme', ' Ms', ' Lady', ' Mlle', ' the Countess'], 'Miss', 
                       inplace = True)
train['Title'].replace([' Don', ' Rev', ' Dr', ' Major', ' Sir', ' Col', ' Capt', ' Jonkheer'], 'Noble/Rev', 
                       inplace = True)
train['Title'].replace(' Mr', 'Mr', 
                       inplace = True)
train['Title'].replace(' Mrs', 'Mrs', 
                       inplace = True)
train['Title'].replace(' Master', 'Master', 
                       inplace = True)

# %%
train.groupby('Title').Survived.count()
# Out:
# Title
# Master        40
# Miss         188
# Mr           517
# Mrs          125
# Noble/Rev     21
# Name: Survived, dtype: int64

# %%
train[train['Title'] == ' Don']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Surname, Title, Firstname]
# Index: []

# %%
plt.figure(figsize=(10, 16))
sns.boxplot(x="Title", y="Age",
            data=train)

# %% [markdown]
# # Lets create a new feature called is_married

# %%
# Get list of surnames of all Mrs
mrs_surname = train[train['Title'] == 'Mrs'].Surname.unique()

# People are married if they have a Mrs title or if they are a Mr with a surname in mrs_surname and SibSp > 0
males_married = train[(train['Surname'].isin(mrs_surname)) & (train['Title'] == 'Mr') & (train['SibSp'] > 0)]
females_married = train[train['Title'] == "Mrs"]
married = pd.concat([males_married, females_married], axis = 0)

# %%
train['Married'] = 1*train.PassengerId.isin(married.PassengerId)
train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 5              6         0       3    male   NaN      0      0
# 6              7         0       1    male  54.0      0      0
# 7              8         0       3    male   2.0      3      1
# 8              9         1       3  female  27.0      0      2
# 9             10         1       2  female  14.0      1      0
# 10            11         1       3  female   4.0      1      1
# 11            12         1       1  female  58.0      0      0
# 12            13         0       3    male  20.0      0      0
# 13            14         0       3    male  39.0      1      5
# ...

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Married        -0.012757  0.240235 -0.176509  0.193056  0.148224  0.251381
#
#                  Fare   Married
# PassengerId  0.012658 -0.012757
# Survived     0.257307  0.240235
# Pclass      -0.549500 -0.176509
# Age          0.096067  0.193056
# SibSp        0.159651  0.148224
# Parch        0.216225  0.251381
# Fare         1.000000  0.122630
# ...
